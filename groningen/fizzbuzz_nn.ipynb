# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
def binary_encode(i, num_digits):
    return np.array([i >> d & 1 for d in range(num_digits)])
def fizz_buzz_encode(i):
    if   i % 15 == 0: return 0#np.array([0, 0, 0, 1])
    elif i % 5  == 0: return 1 #np.array([0, 0, 1, 0])
    elif i % 3  == 0: return 2#np.array([0, 1, 0, 0])
    else:             return 3#np.array([1, 0, 0, 0])

def invert(label, sample):
    if label == 3:
        return sample
    else:
        return {0:'fizzbuzz', 1:'fizz',2:'buzz'}[label]

# %%
def generate_training(num_digits, therange):
    for i in range(*therange):
        yield binary_encode(i, num_digits)
names=[str(i) for i in range(10)]
train_x = pd.DataFrame((i for i in generate_training(10,(101,1024))), columns=names)
test_range = (0,100)
train_range = (101,1024)
train_y = np.asarray([fizz_buzz_encode(i) for i in range(*train_range)])
test_x = pd.DataFrame((i for i in generate_training(10,test_range)),columns=names)
test_y = np.asarray([fizz_buzz_encode(i) for i in range(*test_range)])

def train_input_fn(features, labels, batch_size=20):
    """An input function for training"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))#.map(namer)
    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat(100).batch(batch_size)
    # Return the dataset.
    iterator = dataset.make_one_shot_iterator()
    data, labels = iterator.get_next()
    return data, labels
def test_input_fn(features, labels, batch_size=20):
    """An input function for evaluation or prediction"""
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))#.map(namer)
    # Batch the examples
    assert batch_size is not None, "batch_size must not be None"
    dataset = dataset.batch(batch_size)
    # Return the dataset.
    iterator = dataset.make_one_shot_iterator()
    data, labels = iterator.get_next()
    return data, labels

# %%
def main(train_x, train_y, test_x, test_y):
    my_feature_columns = [tf.feature_column.numeric_column(key=str(k))
                          for k in range(10)]

    # Build 2 hidden layer DNN with 10, 10 units respectively.
    classifier = tf.estimator.DNNClassifier(
        feature_columns=my_feature_columns,
        # The model must choose between 4 classes
        n_classes=4,
        # Two hidden layers of 100 nodes each.
        hidden_units=[100, 100]
        )

    # Train the Model.
    classifier.train(input_fn=lambda:train_input_fn(train_x, train_y))

    # Evaluate the model.
    eval_result = classifier.evaluate(
        input_fn=lambda:test_input_fn(test_x, test_y))

    print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
    predictions = classifier.predict(
        input_fn=lambda:test_input_fn(test_x,test_y))
    formatted = [invert(pred.get('class_ids')[0], idx)
                for idx, pred in enumerate(predictions)]
    expected = [invert(fizz_buzz_encode(i),i) for i, p in enumerate(test_y)]
    return expected, formatted
e, f = main(train_x, train_y, test_x, test_y)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpgwbshf2i
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_task_id': 0, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_tf_random_seed': None, '_service': None, '_save_checkpoints_secs': 600, '_task_type': 'worker', '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f91790f5ac8>, '_model_dir': '/tmp/tmpgwbshf2i', '_session_config': None, '_log_step_count_steps': 100, '_master': '', '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into
# INFO:tensorflow:global_step/sec: 634.671
# INFO:tensorflow:loss = 0.35128483, step = 2901 (0.158 sec)
# INFO:tensorflow:global_step/sec: 621.694
# INFO:tensorflow:loss = 0.22461173, step = 3001 (0.161 sec)
# INFO:tensorflow:global_step/sec: 650.269
# INFO:tensorflow:loss = 0.12842223, step = 3101 (0.154 sec)
# INFO:tensorflow:global_step/sec: 606.845
# INFO:tensorflow:loss = 0.2927072, step = 3201 (0.165 sec)
# INFO:tensorflow:global_step/sec: 543.271
# INFO:tensorflow:loss = 0.19645259, step = 3301 (0.184 sec)
# INFO:tensorflow:global_step/sec: 645.047
# INFO:tensorflow:loss = 0.13983357, step = 3401 (0.155 sec)
# INFO:tensorflow:global_step/sec: 588.052
# INFO:tensorflow:loss = 0.16372055, step = 3501 (0.170 sec)
# INFO:tensorflow:global_step/sec: 604.731
# INFO:tensorflow:loss = 0.12120432, step = 3601 (0.165 sec)
# INFO:tensorflow:global_step/sec: 615.387
# INFO:tensorflow:loss = 0.18765357, step = 3701 (0.162 sec)
# INFO:tensorflow:global_step/sec: 648.898
# INFO:tensorflow:loss = 0.10328377, step = 3801 (0.154 sec)
# INFO:tensorflow:global_step/sec: 615.471
# INFO:tensorflow:loss = 0.53258705, step = 3901 (0.163 sec)
# INFO:tensorflow:global_step/sec: 580.58
# INFO:tensorflow:loss = 0.15466759, step = 4001 (0.172 sec)
# INFO:tensorflow:global_step/sec: 620.793
# INFO:tensorflow:loss = 0.079492696, step = 4101 (0.161 sec)
# INFO:tensorflow:global_step/sec: 611.116
# INFO:tensorflow:loss = 0.12579644, step = 4201 (0.164 sec)
# INFO:tensorflow:global_step/sec: 602.645
# INFO:tensorflow:loss = 0.11674604, step = 4301 (0.166 sec)
# INFO:tensorflow:global_step/sec: 622.125
# INFO:tensorflow:loss = 0.12467589, step = 4401 (0.161 sec)
# INFO:tensorflow:global_step/sec: 644.351
# INFO:tensorflow:loss = 0.13365838, step = 4501 (0.155 sec)
# INFO:tensorflow:global_step/sec: 573.709
# INFO:tensorflow:loss = 0.13127458, step = 4601 (0.174 sec)
# INFO:tensorflow:Saving checkpoints for 4615 into /tmp/tmpgwbshf2i/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.048289847.
# INFO:tensorflow:Starting evaluation at 2018-03-04-00:58:43
# INFO:tensorflow:Restoring parameters from /tmp/tmpgwbshf2i/model.ckpt-4615
# INFO:tensorflow:Finished evaluation at 2018-03-04-00:58:43
# INFO:tensorflow:Saving dict for global step 4615: accuracy = 0.88, average_loss = 0.4168265, global_step = 4615, loss = 8.336531
#
# Test set accuracy: 0.880
#
# INFO:tensorflow:Restoring parameters from /tmp/tmpgwbshf2i/model.ckpt-4615

# %%
for expected, got in zip(e,f):
    print('answer is {}, neural net predicted {}'.format(expected, got))
# Out:
# answer is fizzbuzz, neural net predicted 0
# answer is 1, neural net predicted 1
# answer is 2, neural net predicted buzz
# answer is buzz, neural net predicted 3
# answer is 4, neural net predicted fizz
# answer is fizz, neural net predicted buzz
# answer is buzz, neural net predicted 6
# answer is 7, neural net predicted 7
# answer is 8, neural net predicted buzz
# answer is buzz, neural net predicted fizz
# answer is fizz, neural net predicted 10
# answer is 11, neural net predicted buzz
# answer is buzz, neural net predicted 12
# answer is 13, neural net predicted 13
# answer is 14, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 15
# answer is 16, neural net predicted 16
# answer is 17, neural net predicted buzz
# answer is buzz, neural net predicted 18
# answer is 19, neural net predicted fizz
# answer is fizz, neural net predicted 20
# answer is buzz, neural net predicted 21
# answer is 22, neural net predicted 22
# answer is 23, neural net predicted buzz
# answer is buzz, neural net predicted fizz
# answer is fizz, neural net predicted 25
# answer is 26, neural net predicted buzz
# answer is buzz, neural net predicted 27
# answer is 28, neural net predicted 28
# answer is 29, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 30
# answer is 31, neural net predicted 31
# answer is 32, neural net predicted buzz
# answer is buzz, neural net predicted 33
# answer is 34, neural net predicted fizz
# answer is fizz, neural net predicted buzz
# answer is buzz, neural net predicted 36
# answer is 37, neural net predicted 37
# answer is 38, neural net predicted buzz
# answer is buzz, neural net predicted fizz
# answer is fizz, neural net predicted 40
# answer is 41, neural net predicted buzz
# answer is buzz, neural net predicted 42
# answer is 43, neural net predicted 43
# answer is 44, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 45
# answer is 46, neural net predicted 46
# answer is 47, neural net predicted buzz
# answer is buzz, neural net predicted 48
# answer is 49, neural net predicted fizz
# answer is fizz, neural net predicted buzz
# answer is buzz, neural net predicted 51
# answer is 52, neural net predicted 52
# answer is 53, neural net predicted buzz
# answer is buzz, neural net predicted fizz
# answer is fizz, neural net predicted 55
# answer is 56, neural net predicted buzz
# answer is buzz, neural net predicted 57
# answer is 58, neural net predicted 58
# answer is 59, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 60
# answer is 61, neural net predicted 61
# answer is 62, neural net predicted buzz
# answer is buzz, neural net predicted 63
# answer is 64, neural net predicted fizz
# answer is fizz, neural net predicted buzz
# answer is buzz, neural net predicted 66
# answer is 67, neural net predicted 67
# answer is 68, neural net predicted buzz
# answer is buzz, neural net predicted 69
# answer is fizz, neural net predicted 70
# answer is 71, neural net predicted buzz
# answer is buzz, neural net predicted 72
# answer is 73, neural net predicted 73
# answer is 74, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 75
# answer is 76, neural net predicted 76
# answer is 77, neural net predicted buzz
# answer is buzz, neural net predicted 78
# answer is 79, neural net predicted fizz
# answer is fizz, neural net predicted 80
# answer is buzz, neural net predicted 81
# answer is 82, neural net predicted 82
# answer is 83, neural net predicted buzz
# answer is buzz, neural net predicted fizz
# answer is fizz, neural net predicted 85
# answer is 86, neural net predicted buzz
# answer is buzz, neural net predicted 87
# answer is 88, neural net predicted 88
# answer is 89, neural net predicted fizzbuzz
# answer is fizzbuzz, neural net predicted 90
# answer is 91, neural net predicted 91
# answer is 92, neural net predicted buzz
# answer is buzz, neural net predicted 93
# answer is 94, neural net predicted fizz
# answer is fizz, neural net predicted buzz
# answer is buzz, neural net predicted 96
# answer is 97, neural net predicted 97
# answer is 98, neural net predicted buzz
